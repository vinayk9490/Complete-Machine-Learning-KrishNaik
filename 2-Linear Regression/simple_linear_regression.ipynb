# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.shape, df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  23 non-null     int64
#  1   Height  23 non-null     int64
# dtypes: int64(2)
# memory usage: 500.0 bytes
# ((23, 2), None)

# %%
df.tail()
# Out:
#     Weight  Height
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
df.isna().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %%
#scatter plot
plt.scatter(df['Height'], df['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height vs Weight')
plt.show()

# %%
#Coorelation between height and weight
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# Always independent variables should be of 2D/Dataframe format and dependent variable/target should be in the form of 1D

# %%
#Divide the features into independednt and dependent features
X = df[['Weight']]
print(type(X))
X.shape
# Out:
# <class 'pandas.DataFrame'>
# (23, 1)

# %%
y = df['Height']
y.shape
# Out:
# (23,)

# %%
#train, test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (17, 1) (17,)
# (6, 1) (6,)

# %%
#Data Standardization 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([17.2982057]), np.float64(156.47058823529412))

# %%
#plot the training data's best fit line
plt.scatter(X_train, y_train, color='blue', label='Training Data')
plt.plot(X_train, model.predict(X_train), color='red', label='Best Fit Line')

# %%
#prediction for test data
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([162.26499721, 162.26499721, 127.68347133, 180.07972266,
#        148.64197186, 190.55897293])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 114.84069295228699
# Mean Absolute Error: 9.66512588679501
# Root Mean Squared Error: 10.716374991212605

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
print(f'R2 Score: {score}')
# Out:
# R2 Score: 0.7360826717981276
